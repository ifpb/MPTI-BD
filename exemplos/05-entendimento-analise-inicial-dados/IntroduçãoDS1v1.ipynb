# %% [markdown]
# ### **Introdução**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Exemplos de análise e descrição inicial em um dataset

# %%
# importando a lib pandas
import pandas as pd

# %%
filmes = pd.read_csv('/content/drive/MyDrive/Datasets/tmdb_5000_movies (1).csv')

# %%
filmes.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
filmes.tail(5)
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
# metadados descritivos
filmes.shape
# Out:
# (4803, 20)

# %%
print('Metadados descritivos do dataset: {} registros (filmes) e {} variáveis'.format(filmes.shape[0], filmes.shape[1]))
# Out:
# Metadados descritivos do dataset: 4803 registros (filmes) e 20 variáveis

# %%
# conhecendo o dataset e sua estrutura de metadados
filmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
pd.DataFrame(filmes.dtypes)
# Out:
#                             0
# budget                  int64
# genres                 object
# homepage               object
# id                      int64
# keywords               object
# original_language      object
# original_title         object
# overview               object
# popularity            float64
# production_companies   object
# production_countries   object
# release_date           object
# revenue                 int64
# runtime               float64
# spoken_languages       object
# status                 object
# tagline                object
# title                  object
# vote_average          float64
# vote_count              int64

# %%
tipos = pd.DataFrame(filmes.dtypes, columns = ['Tipos'])
tipos.columns.name = 'Variáveis'
tipos
# Out:
# Variáveis               Tipos
# budget                  int64
# genres                 object
# homepage               object
# id                      int64
# keywords               object
# original_language      object
# original_title         object
# overview               object
# popularity            float64
# production_companies   object
# production_countries   object
# release_date           object
# revenue                 int64
# runtime               float64
# spoken_languages       object
# status                 object
# tagline                object
# title                  object
# vote_average          float64
# vote_count              int64

# %%
filmes.runtime
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
filmes.budget
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
filmes['original_language']
# Out:
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en
#         ..
# 4798    es
# 4799    en
# 4800    en
# 4801    en
# 4802    en
# Name: original_language, Length: 4803, dtype: object

# %%
#consultando e mostrando filmes com orçamento maior que valor 
display(filmes[filmes.budget > 300000000])
# Out:
#        budget                                             genres  \
# 17  380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                              homepage    id  \
# 17  http://disney.go.com/pirates/index-on-stranger...  1865
#
#                                              keywords original_language  \
# 17  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
#
#                                  original_title  \
# 17  Pirates of the Caribbean: On Stranger Tides
#
#                                              overview  popularity  \
# 17  Captain Jack Sparrow crosses paths with a woma...  135.413856
#
#                                  production_companies  \
# 17  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                  production_countries release_date  \
# 17  [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
#
# ...

# %%
#selecionando duas linhas e duas colunas usando o índice numérico
filmes.iloc[[10,11], [5,7]]
# Out:
#    original_language                                           overview
# 10                en  Superman returns to discover his 5-year absenc...
# 11                en  Quantum of Solace continues the adventures of ...

# %%
#selecionando duas linhas e duas colunas 
filmes.loc[[10,11], ['overview', 'vote_count']]
# Out:
#                                              overview  vote_count
# 10  Superman returns to discover his 5-year absenc...        1400
# 11  Quantum of Solace continues the adventures of ...        2965

# %%
#obtendo todas as linhas com duas colunas apenas
filmes.loc[:, ['overview','tagline']]
# Out:
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                 tagline
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# ...

# %%
filmes.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
filmes.isnull().tail(10)
# Out:
#       budget  genres  homepage     id  keywords  original_language  \
# 4793   False   False      True  False     False              False
# 4794   False   False      True  False     False              False
# 4795   False   False      True  False     False              False
# 4796   False   False     False  False     False              False
# 4797   False   False      True  False     False              False
# 4798   False   False      True  False     False              False
# 4799   False   False      True  False     False              False
# 4800   False   False     False  False     False              False
# 4801   False   False     False  False     False              False
# 4802   False   False      True  False     False              False
#
#       original_title  overview  popularity  production_companies  \
# 4793           False     False       False                 False
# 4794           False     False       False                 False
# ...

# %%
filmes[filmes['homepage'].isnull()]
# Out:
#          budget                                             genres homepage  \
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...      NaN
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...      NaN
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...      NaN
# 33    210000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...      NaN
# 34    200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...      NaN
# ...         ...                                                ...      ...
# 4795          0                      [{"id": 18, "name": "Drama"}]      NaN
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...      NaN
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...      NaN
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...      NaN
# 4802          0                [{"id": 99, "name": "Documentary"}]      NaN
#
# ...

# %%
filmes[filmes['homepage'].isnull()].head(5)
# Out:
#        budget                                             genres homepage  \
# 15  225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...      NaN
# 24  207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...      NaN
# 27  209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...      NaN
# 33  210000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...      NaN
# 34  200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...      NaN
#
#        id                                           keywords  \
# 15   2454  [{"id": 818, "name": "based on novel"}, {"id":...
# 24    254  [{"id": 774, "name": "film business"}, {"id": ...
# 27  44833  [{"id": 1721, "name": "fight"}, {"id": 4410, "...
# 33  36668  [{"id": 1852, "name": "mutant"}, {"id": 8828, ...
# 34  62211  [{"id": 1299, "name": "monster"}, {"id": 5984,...
#
#    original_language                            original_title  \
# 15                en  The Chronicles of Narnia: Prince Caspian
# ...

# %%
#remove as linhas que tenham valor nulo 
filmes1 = filmes.dropna()

# %%
filmes1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4781      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4801          0                                                 []
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %%
filmes1[filmes1['homepage'].isnull()].shape[0]
# Out:
# 0

# %%
#Remove as colunas com valor nulo
filmes2 = filmes.dropna(axis=1)

# %%
filmes2
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
filmes2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   popularity            4803 non-null   float64
#  7   production_companies  4803 non-null   object
#  8   production_countries  4803 non-null   object
#  9   revenue               4803 non-null   int64
#  10  spoken_languages      4803 non-null   object
#  11  status                4803 non-null   object
#  12  title                 4803 non-null   object
#  13  vote_average          4803 non-null   float64
#  14  vote_count            4803 non-null   int64
# ...

# %%
# remove com base em um subconjunto de colunas
filmes3 = filmes.dropna(subset=['homepage', 'tagline'])

# %%
filmes3.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#Voltando a ver filmes com os dados originais
filmes[filmes['tagline'].isnull()].shape[0]
# Out:
# 844

# %%
filmes['tagline'].tail(25)
# Out:
# 4778                               Vengeance is ruthless.
# 4779                                                  NaN
# 4780                                                  NaN
# 4781         Getting divorced does funny things to a girl
# 4782                                                  NaN
# 4783                                           nederlands
# 4784                                                  NaN
# 4785                                                  NaN
# 4786                                                  NaN
# 4787                                 May The Best Man Win
# 4788                           An exercise in poor taste.
# 4789            When you don't have a choice, you change.
# 4790                                                  NaN
# 4791                      Everything You've Heard is True
# 4792                             Madness. Terror. Murder.
# 4793                Two gangs. One secret. One crossroad.
# ...

# %%
#substituindo o valor ausente em tagline por 'Não informado'
filmes4 = filmes.fillna({'tagline': 'Não informado'})

# %%
filmes4['tagline'].tail(10)
# Out:
# 4793                Two gangs. One secret. One crossroad.
# 4794                                        Não informado
# 4795              Sometimes you've got to break the rules
# 4796                   What happens if it actually works?
# 4797                                        Não informado
# 4798    He didn't come looking for trouble, but troubl...
# 4799    A newlywed couple's honeymoon is upended by th...
# 4800                                        Não informado
# 4801                             A New Yorker in Shanghai
# 4802                                        Não informado
# Name: tagline, dtype: object

# %%
#uma análise mais descritiva
filmes.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
filmes['popularity'].describe().round(2)
# Out:
# count    4803.00
# mean       21.49
# std        31.82
# min         0.00
# 25%         4.67
# 50%        12.92
# 75%        28.31
# max       875.58
# Name: popularity, dtype: float64

# %%
filmes['popularity'].aggregate(['min', 'max', 'sum'])
# Out:
# min         0.000000
# max       875.581305
# sum    103227.519725
# Name: popularity, dtype: float64

# %%
filmes['budget'].mean()
# Out:
# 29045039.87528628
